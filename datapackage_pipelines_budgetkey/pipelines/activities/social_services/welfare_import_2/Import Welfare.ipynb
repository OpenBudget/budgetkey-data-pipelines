# %%
import dataflows as DF
import glob
import requests
import json

# %%
GEOS={
    'ירושלים ויו"ש': 'yv-sh',
    'דרום': 'drvm',
    'מרכז': 'mrkz',
    'צפון': 'tspvn'
}

# %%
ERRORS = []
items = []

# %%
social_services = requests.get('https://data-input.obudget.org/api/datarecords/social_service').json()
social_services = [x['value'] for x in social_services['result']]
social_services = dict((x['catalog_number'], x['name']) for x in social_services if 'catalog_number' in x)
social_services
# Out:
# {'870': 'תכנית משכילה - ליווי הורה עצמאי להשכלה גבוהה',
#  '203': 'שירותי סמך מקצועי',
#  '6': 'סל תקשורת לחירשים וכבדי שמיעה',
#  '241': 'אומנה',
#  '126': 'אומנת חירום',
#  '243': 'פנימיות',
#  'אין': 'משפחות מלוות, ילדי נע"מ ומרכזיות חינוכיות בפנימיות ',
#  '245': 'מקלטים לנשים נפגעות אלימות וילדיהן',
#  '150': 'דירות מעבר לנשים נפגעות אלימות וילדיהן',
#  '179': 'מעטפת למרכזי עוצמה - סיוע ליחידים ומשפחות החיים בעוני ',
#  '880': 'מרכזי יום לבני 21+ עם מוגבלות',
#  '713': 'מערך דיור או דירות לוויין',
#  '82': 'דירות בקהילות ייחודיות לאנשים עם מוגבלויות',
#  '712': 'מעונות פנימייה לאנשים עם מוגבלות',
#  '143': 'הוסטל לאנשים עם מוגבלויות',
#  '786': 'מערך דיור לאנשים עם מוגבלויות',
#  '714': 'מכינות הכנה לחיים עצמאיים ותוכנית מעבר עם התנדבות לצבא לצעירים עם מוגבלות',
#  '667': 'שילוב פעוטות עם מוגבלות במעונות יום רגילים',
#  '239': 'פנימיות יום - מסגרת שהייה בקהילה',
#  '336': 'מעברים - תוכנית לפיתוח תעסוקתי-כלכלי-קהילתי במגזר הכפרי',
#  '342': 'מרכזי חוסן קהילתי',
#  '343': 'צח"י - צוותי חוסן וחירום יישוביים',
#  'לא רלוונטי': 'השביל המיטיב \t',
#  '232': 'מרכזי ההגנה לילדים ולנוער',
#  '134': 'מרכזים אזוריים לטיפול בפגיעות מיניות לילדים ובני נוער',
#  '156': 'מרכזי סיוע למשפחות שכולות עקב התאבדות, תאונות דרכים או עבירות המתה',
#  '230': 'יחידה טיפולית-יעוצית (אקסטרנית)',
#  '113': 'קד"מ (קבוצת דיון משפחתית) - חלופה לועדת תכנון טיפול והערכה',
#  '244': 'מרכז חירום לטיפול בילדים והוריהם',
#  '885': 'בית אלה - חלופה אשפוזית לנפגעות תקיפה מינית',
#  '13': 'מיזמים לשינוי עמדות הציבור',
#  '283': 'מסגרת פנימייה לנוער חרדי (נוח"מ)',
#  '279': 'הוסטל לצעירים/ות במצבי סיכון',
#  '49': 'מקלט חירום לנערות וצעירות במצבי סיכון',
#  '276': 'צל"ש (צעירות לקראת שירות) - תכנית הכנה לצבא / שירות לאומי',
#  '186': 'הוסטל טיפולי-שיקומי-תעסוקתי לדרי רחוב',
#  '185': 'בית לחיים לדרי רחוב',
#  '56': 'מית"ר (מרכז יום רב תחומי) לבני נוער במצבי סיכון',
#  '209': 'קהילות טיפוליות (מסגרות חוץ ביתיות לנפגעי התמכרויות)',
#  '540': 'תוכניות לשיקום מונע לעברייני מין בקהילה',
#  '533': 'בתים טיפוליים לגברים הנוהגים באלימות זוגית',
#  '907': '"גשר לעצמאות" - לבוגרי פנימיות ואומנה',
#  '500': 'ליווי בוגרי מעונות חסות הנוער',
#  '494': 'רשות חסות הנוער',
#  '48': 'דירת מעבר לצעירות חרדיות במצבי סיכון',
#  '47': 'דירת מעבר לצעירים/ות במצבי סיכון',
#  '640': 'נופשון לזמן קצוב בבית אבות לאזרח הוותיק',
#  '634': 'בתי אבות לאזרחים ותיקים, עצמאים ותשושים',
#  '142': 'מעון יום שיקומי לפעוטות עם מוגבלות',
#  '37': 'מרכז טיפולי לנפגעי התמכרויות',
#  '270': 'פנימיה לנוער',
#  '535': 'טיפול יום לגברים אלימים',
#  '778': 'קהילה טיפולית לנפגעי התמכרויות',
#  '889': 'משפחות המבקשות להיות מוכרות כמשפחת אומנה',
#  '182': 'קלט חירום לדרי רחוב',
#  '280': 'הוסטלים ודירות מעבר לצעירות חרדיות במצבי סיכון',
#  '949': 'סדנאות הכנה ללימודים אקדמיים לסטודנטים עם מוגבלות בראייה',
#  '178': 'תכנית נושמים לרווחה',
#  '68': 'תכנית רעים לאנשים עם צרכים מיוחדים',
#  '75': 'שילוב צעירים עם מוגבלויות בשירות צבאי',
#  '17': 'תמיכה חזותית לאנשים עם מוגבלויות חושית כפולה (עיוורון וחירשות)',
#  '890': 'תכנית נור לנערות וצעירות בחברה הערבית',
#  '21': 'הדרכה טכנולוגית לבעלי מוגבלות: ראיה, שמיעה, שניהם',
#  '19': 'השאלת עזרים- עיוורים',
#  '946': 'מוקד תמיכה טלפוני לאנשים עם מוגבלות בראייה',
#  '876': 'קהילה נגישה – תוכנית קהילתית לאנשים בוגרים עם מוגבלות',
#  '678': 'מרכזים לחיים עצמאיים לאנשים עם מוגבלות',
#  '669': 'מועדונית שיקומית ומרכז נוער לילדים ונוער עם מוגבלות',
#  '16': 'תוכניות שיקום קבוצתי אינטנסיבי- עיוורים',
#  '9': 'סדנאות שיקום שמיעתי למתחרשים',
#  '681': 'תוכניות פנאי משולבות אנשים עם וללא מוגבלות',
#  '480': 'טיפול לנוער עובר חוק באמצעות פעילות אתגרית',
#  '487': 'משפחה תומכת - תוכנית להורים לנוער עובר חוק יוצאי אתיופיה',
#  '549': '"נסיעה במבחן" - תכנית התערבות קבוצתית למניעת נהיגה מסכנת',
#  '550': 'תוכנית התערבות קבוצתית למניעת נהיגה תחת השפעת אלכוהול',
#  '552': 'תוכניות בשילוב האקדמיה - תוכניות השכלה למבוגרים',
#  '555': 'בתי משפט קהילתיים',
#  '789': 'סגירת תיק בהסדר',
#  '610': 'קהילה תומכת לאזרח הוותיק',
#  '614': 'מועדון מועשר לאזרחים ותיקים',
#  '615': 'מועדוני מופת - מועדונים המעניקים בטחון תזונתי',
#  '83': 'שילוב בתעסוקה נתמכת בקהילה לאנשים עם מוגבלויות',
#  '175': 'תעסוקה לרווחה',
#  '176': 'אשת חיל - תכנית תעסוקה לנשים מתרבויות מסורתיות',
#  '265': 'תוכנית ענ"ן - עסקים נתמכי נכים - תעסוקה לאנשים עם מוגבלויות',
#  '266': 'תוכנית המשך - תוכנית מעבר תעסוקתית',
#  '646': 'יוצרים עתיד - תוכנית מעבר מבית הספר לעולם העבודה',
#  '649': 'מגמה לעתיד - הכשרה מקצועית במסגרת מכללות טכנולוגיות',
#  '139': 'תוכנית יתד לצעירות וצעירים במצבי סיכון',
#  '90': 'תוכניות השכלה ולימודים לאנשים עם מוגבלויות',
#  '671': 'מטפחים לילדים ולבני נוער',
#  '67': 'דיור נתמך לאנשים עם מוגבלויות',
#  '84': 'מרכז אבחון ושיקום לבוגרים עם מוגבלות',
#  '85': 'תוכניות תעסוקה מותאמות לאנשים עם מוגבלויות',
#  '87': 'המשקם - מפעל בשכר לאנשים עם מוגבלויות',
#  '145': 'נופשונים לילדים ולבוגרים עם מוגבלויות',
#  '839': 'תוכניות השכלה והכשרה',
#  '904': 'אומנה לילדים וצעירים עם מוגבלות',
#  '86': 'קבוצות עבודה - מח"ר (מפעלים חברתיים רווחיים) תעשייתי',
#  '147': 'קייטנות לילדים עם מוגבלות',
#  '88': 'מועדונים חברתיים לאנשים עם מוגבלויות',
#  '42': 'תכנית סלע- חונכות לנערים/ות במצבי סיכון ומצוקה',
#  '484': 'מענים להורים לנערים עוברי חוק',
#  '489': 'בדיקות ואבחונים לנוער עובר חוק',
#  '887': 'מרכז לטיפול במכורים להימורים (מיל"ה)',
#  '892': 'תוכנית מעטפת - תכנית ליווי משפחתית מקיפה ועוטפת לנוער עובר חוק',
#  '896': 'שילוב צעירים/ות במצבי סיכון בשירות לאומי-אזרחי',
#  '862': 'מרכזי אבחון הערכה וזכויות \nלאנשים עם מוגבלויות',
#  '895': 'הוסטל חירום לנערות וצעירות מהחברה החרדית',
#  '899': 'מקלט לצעירים יוצאים בשאלה',
#  '906': 'דיורית לצעירות במצבי סיכון',
#  '1': 'החזר מסים על רכישת מכשיר פקסימליה',
#  '5': 'החזר עבור גלאי בכי להורים חירשים וכבדי שמיעה',
#  '14': 'הדרכה שיקומית לאנשים עם מוגבלויות ראייה',
#  '184': 'מסגרות טיפוליות שיקומיות לדרי רחוב',
#  '909': 'מעונות יום',
#  '790': 'סדנת ניהול כלכלת בית לעוברי חוק',
#  '531': 'התערבות קבוצתית להורים שהתנהגו באלימות כלפי ילדיהם',
#  '481': 'דרך המלך - תכנית להכנת נוער עובר חוק לעולם התעסוקה',
#  '483': 'תכנית סיכויים לנוער עובר חוק',
#  '479': 'טיפול אישי, זוגי, משפחתי וקבוצתי לנוער עובר חוק',
#  '486': 'צדק מאחה - קד"ם (קבוצות דיון משפחתיות) והנ"ף (היוועדות נפגע-פוגע) – טיפול אישי, זוגי, משפחתי וקבוצתי',
#  '202': 'סיוע כספי לילדים יתומים',
#  '338': 'קהילת האימוץ',
#  '246': 'משפחות המבקשות לאמץ',
#  '43': 'מרכזי קהילה לבוגרים יוצאים בשאלה',
#  '901': 'מרכזי טיפול לבוגרים יוצאים בשאלה',
#  '347': 'מתנדבי חו"ל - VOIS',
#  '348': 'התנדבות למען ועל ידי האזרח הוותיק',
#  '341': 'מרכזי טיפול אישי, זוגי, משפחתי וקבוצתי ודיאלוג בקהילה',
#  '220': 'חוק הנוער (טיפול והשגחה)',
#  '256': 'תוכניות בקהילה לנוער במצבי סיכון',
#  '262': 'ליווי קבוצתי לבני נוער מקהילת הלהט"ב',
#  '269': 'ליווי סוציאלי לבני נוער צעירים/ות מקהילת הלהט"ב',
#  '44': 'תוכנית "משלי"- השלמת השכלה תיכונית לצעירים/ות במכינה קדם אקדמית (כולל הפעלת תוכנית אוניברסיטאית בסיסית)',
#  '201': 'מוקד משרד העבודה והרווחה - 118',
#  '908': 'סל שעות גמיש - סיוע במימון צהרונים, שמרטף וקייטנות לחד הוריים (הורים עצמאיים)',
#  '329': 'מקלטים לנפגעי עבדות וסחר בבני אדם',
#  '349': 'שירות לאומי אזרחי',
#  '351': 'הרשת להתנדבות ישראלית',
#  '7': 'שירותי תרגום שפת סימנים/תמלול/העתקת סימנים',
#  '8': 'מרכז תקשורת',
#  '3': 'תחנות מידע לאנשים עם לקות שמיעה',
#  '101': 'מרכזי הדרכה, ייעוץ וטיפול בתחום המיני-חברתי ובמצבי משבר',
#  '641': 'וועדת אבחון לילדים ואנשים עם מוגבלויות שכלית התפתחותית',
#  '608': 'מרכזי יום לאזרח הוותיק',
#  '12': 'תחנות מידע וייעוץ ללקויי ראיה ועיוורים',
#  '15': 'מכונים לשיקום הראייה הירודה',
#  '25': 'כלבי נחייה לאנשים עם מוגבלויות בראייה',
#  '28': 'קורסים לשפת הסימנים',
#  '648': 'תעסוקה מוגנת - מרכזי תעסוקה לאנשים עם מוגבלויות',
#  '835': 'חונך לילד עיוור או לילד רואה להורים עיוורים'}

# %%
filenames = glob.glob('*.xlsx')
filenames = ['מינהל מוגבלויות סופי.xlsx'] # Override
filenames
# Out:
# ['מינהל מוגבלויות סופי.xlsx']

# %%
FIELDS = dict(
    catalog_number=["מס' קטלוגי", "מספר קטלוגי"],
    year=['שנה'],
    code=['תקנה תקציבית'],
    beneficiary_num=['כמות מושמים'],
    entity_id=['ח.פ מסגרת'],
    amount=['סך תשלומים'],
    tender=['מכרז'],
    geo=['מחוז המסגרת']
)

# %%
def loader():
    return DF.Flow(
        *[
            DF.load(file)
            for file in filenames
        ],
        DF.concatenate(FIELDS),
        DF.update_resource(-1, name='activities')
    )
loader().process()
# Out:
# (<datapackage.package.Package at 0x132a90450>, {})

# %%
def manualBudget():
    fields = ['catalog_number', 'year', 'amount']
    return DF.Flow(
        loader(),
        DF.select_fields(fields),
        DF.join_with_self('activities', ['catalog_number', 'year'], dict(catalog_number=None, year=None, amount=dict(aggregate='sum'))),
        DF.filter_rows(lambda r: r['amount'] != 0),
        DF.add_field('manualBudget', 'object', lambda r: dict(
            year=r['year'], approved=r['amount'], executed=r['amount']
        )),
        DF.join_with_self('activities', ['catalog_number'], dict(catalog_number=None, manualBudget=dict(aggregate='array'))),
        DF.select_fields(['catalog_number', 'manualBudget']),
        DF.set_type('manualBudget', transform=lambda v: sorted(v, key=lambda i: i['year'], reverse=True)),
#         DF.set_type('manualBudget', type='object', transform=lambda v: dict(manualBudget=v)),
        DF.printer(tablefmt='html'),
    ).results()[0][0]
   
items.extend(manualBudget())
# Out:
# <h3>activities</h3>
# <table>
# <thead>
# <tr><th style="text-align: right;">  #</th><th style="text-align: right;">    catalog_number
# (integer)</th><th>manualBudget
# (array)                                                                                                         </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  1</td><td style="text-align: right;"> 14</td><td>[{&#x27;approved&#x27;: 7913073.16, &#x27;executed&#x27;: 7913073.16, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 8982450.52, &#x27;executed&#x27; ...</td></tr>
# <tr><td style="text-align: right;">  2</td><td style="text-align: right;">142</td><td>[{&#x27;approved&#x27;: 211489092.88000003, &#x27;executed&#x27;: 211489092.88000003, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 208092 ...</td></tr>
# <tr><td style="text-align: right;">  3</td><td style="text-align: right;">143</td><td>[{&#x27;approved&#x27;: 354153830.7099999, &#x27;executed&#x27;: 354153830.7099999, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 32994249 ...</td></tr>
# <tr><td style="text-align: right;">  4</td><td style="text-align: right;">145</td><td>[{&#x27;approved&#x27;: 20554148.87, &#x27;executed&#x27;: 20554148.87, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 30711850.190000005,  ...</td></tr>
# <tr><td style="text-align: right;">  5</td><td style="text-align: right;">147</td><td>[{&#x27;approved&#x27;: 824783.7, &#x27;executed&#x27;: 824783.7, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 1607757.05, &#x27;executed&#x27;: 16 ...</td></tr>
# <tr><td style="text-align: right;">  6</td><td style="text-align: right;">648</td><td>[{&#x27;approved&#x27;: 14181149.750000002, &#x27;executed&#x27;: 14181149.750000002, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 157525 ...</td></tr>
# <tr><td style="text-align: right;">  7</td><td style="text-align: right;">667</td><td>[{&#x27;approved&#x27;: 577728.39, &#x27;executed&#x27;: 577728.39, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 672644.51, &#x27;executed&#x27;: 6 ...</td></tr>
# <tr><td style="text-align: right;">  8</td><td style="text-align: right;">712</td><td>[{&#x27;approved&#x27;: 1561394568.3699996, &#x27;executed&#x27;: 1561394568.3699996, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 145572 ...</td></tr>
# <tr><td style="text-align: right;">  9</td><td style="text-align: right;">713</td><td>[{&#x27;approved&#x27;: 35530534.88999999, &#x27;executed&#x27;: 35530534.88999999, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 32095481 ...</td></tr>
# <tr><td style="text-align: right;"> 10</td><td style="text-align: right;">714</td><td>[{&#x27;approved&#x27;: 74329981.05, &#x27;executed&#x27;: 74329981.05, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 62762107.54000001, &#x27; ...</td></tr>
# <tr><td style="text-align: right;"> 11</td><td style="text-align: right;"> 75</td><td>[{&#x27;approved&#x27;: 6455537.73, &#x27;executed&#x27;: 6455537.73, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 4349695.130000001, &#x27;ex ...</td></tr>
# <tr><td style="text-align: right;"> 12</td><td style="text-align: right;">786</td><td>[{&#x27;approved&#x27;: 585434172.5199999, &#x27;executed&#x27;: 585434172.5199999, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 51619954 ...</td></tr>
# <tr><td style="text-align: right;"> 13</td><td style="text-align: right;"> 82</td><td>[{&#x27;approved&#x27;: 57982264.41, &#x27;executed&#x27;: 57982264.41, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 29591074.410000004,  ...</td></tr>
# <tr><td style="text-align: right;"> 14</td><td style="text-align: right;"> 84</td><td>[{&#x27;approved&#x27;: 4219503.28, &#x27;executed&#x27;: 4219503.28, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 7666073.649999999, &#x27;ex ...</td></tr>
# <tr><td style="text-align: right;"> 15</td><td style="text-align: right;"> 86</td><td>[{&#x27;approved&#x27;: 11520163.54, &#x27;executed&#x27;: 11520163.54, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 11294779.23, &#x27;execut ...</td></tr>
# <tr><td style="text-align: right;"> 16</td><td style="text-align: right;"> 87</td><td>[{&#x27;approved&#x27;: 608183.6599999999, &#x27;executed&#x27;: 608183.6599999999, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 642653.4 ...</td></tr>
# <tr><td style="text-align: right;"> 17</td><td style="text-align: right;"> 88</td><td>[{&#x27;approved&#x27;: 537020.24, &#x27;executed&#x27;: 537020.24, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 530883.2599999999, &#x27;exec ...</td></tr>
# <tr><td style="text-align: right;"> 18</td><td style="text-align: right;">880</td><td>[{&#x27;approved&#x27;: 53385291.48, &#x27;executed&#x27;: 53385291.48, &#x27;year&#x27;: 2020}, {&#x27;approved&#x27;: 48853147.09000001, &#x27; ...</td></tr>
# </tbody>
# </table>

# %%
def beneficiaries():
    fields = ['catalog_number', 'year', 'beneficiary_num']
    return DF.Flow(
        loader(),
        DF.select_fields(fields),
        DF.join_with_self('activities', ['catalog_number', 'year',], dict(catalog_number=None, year=None, beneficiary_num=dict(aggregate='sum'))),
        DF.filter_rows(lambda r: r['beneficiary_num'] != 0),
        DF.add_field('beneficiaries', 'object', lambda r: dict(
            year=r['year'], num_beneficiaries=r['beneficiary_num']
        )),
        DF.join_with_self('activities', ['catalog_number'], dict(catalog_number=None, beneficiaries=dict(aggregate='array'))),
        DF.select_fields(['catalog_number', 'beneficiaries']),
        DF.set_type('beneficiaries', transform=lambda v: sorted(v, key=lambda i: i['year'], reverse=True)),
#         DF.set_type('beneficiaries', type='object', transform=lambda v: dict(beneficiaries=v)),
        DF.printer(tablefmt='html'),
    ).results()[0][0]
   
items.extend(beneficiaries())
# Out:
# <h3>activities</h3>
# <table>
# <thead>
# <tr><th style="text-align: right;">  #</th><th style="text-align: right;">    catalog_number
# (integer)</th><th>beneficiaries
# (array)                                                                                                         </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  1</td><td style="text-align: right;"> 14</td><td>[{&#x27;num_beneficiaries&#x27;: 2479, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 2690, &#x27;year&#x27;: 2019}, {&#x27;num_benefic ...</td></tr>
# <tr><td style="text-align: right;">  2</td><td style="text-align: right;">142</td><td>[{&#x27;num_beneficiaries&#x27;: 4142, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 6887, &#x27;year&#x27;: 2019}, {&#x27;num_benefic ...</td></tr>
# <tr><td style="text-align: right;">  3</td><td style="text-align: right;">143</td><td>[{&#x27;num_beneficiaries&#x27;: 2488, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 4842, &#x27;year&#x27;: 2019}, {&#x27;num_benefic ...</td></tr>
# <tr><td style="text-align: right;">  4</td><td style="text-align: right;">145</td><td>[{&#x27;num_beneficiaries&#x27;: 5033, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 10880, &#x27;year&#x27;: 2019}, {&#x27;num_benefi ...</td></tr>
# <tr><td style="text-align: right;">  5</td><td style="text-align: right;">147</td><td>[{&#x27;num_beneficiaries&#x27;: 985, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 2038, &#x27;year&#x27;: 2019}, {&#x27;num_benefici ...</td></tr>
# <tr><td style="text-align: right;">  6</td><td style="text-align: right;">648</td><td>[{&#x27;num_beneficiaries&#x27;: 1162, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 1739, &#x27;year&#x27;: 2019}, {&#x27;num_benefic ...</td></tr>
# <tr><td style="text-align: right;">  7</td><td style="text-align: right;">667</td><td>[{&#x27;num_beneficiaries&#x27;: 115, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 219, &#x27;year&#x27;: 2019}, {&#x27;num_beneficia ...</td></tr>
# <tr><td style="text-align: right;">  8</td><td style="text-align: right;">712</td><td>[{&#x27;num_beneficiaries&#x27;: 8491, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 16707, &#x27;year&#x27;: 2019}, {&#x27;num_benefi ...</td></tr>
# <tr><td style="text-align: right;">  9</td><td style="text-align: right;">713</td><td>[{&#x27;num_beneficiaries&#x27;: 238, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 407, &#x27;year&#x27;: 2019}, {&#x27;num_beneficia ...</td></tr>
# <tr><td style="text-align: right;"> 10</td><td style="text-align: right;">714</td><td>[{&#x27;num_beneficiaries&#x27;: 641, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 1075, &#x27;year&#x27;: 2019}, {&#x27;num_benefici ...</td></tr>
# <tr><td style="text-align: right;"> 11</td><td style="text-align: right;"> 75</td><td>[{&#x27;num_beneficiaries&#x27;: 1499, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 1326, &#x27;year&#x27;: 2019}, {&#x27;num_benefic ...</td></tr>
# <tr><td style="text-align: right;"> 12</td><td style="text-align: right;">786</td><td>[{&#x27;num_beneficiaries&#x27;: 4273, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 8095, &#x27;year&#x27;: 2019}, {&#x27;num_benefic ...</td></tr>
# <tr><td style="text-align: right;"> 13</td><td style="text-align: right;"> 82</td><td>[{&#x27;num_beneficiaries&#x27;: 544, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 651, &#x27;year&#x27;: 2019}, {&#x27;num_beneficia ...</td></tr>
# <tr><td style="text-align: right;"> 14</td><td style="text-align: right;"> 84</td><td>[{&#x27;num_beneficiaries&#x27;: 679, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 834, &#x27;year&#x27;: 2019}, {&#x27;num_beneficia ...</td></tr>
# <tr><td style="text-align: right;"> 15</td><td style="text-align: right;"> 86</td><td>[{&#x27;num_beneficiaries&#x27;: 711, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 1199, &#x27;year&#x27;: 2019}, {&#x27;num_benefici ...</td></tr>
# <tr><td style="text-align: right;"> 16</td><td style="text-align: right;"> 87</td><td>[{&#x27;num_beneficiaries&#x27;: 68, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 69, &#x27;year&#x27;: 2019}, {&#x27;num_beneficiari ...</td></tr>
# <tr><td style="text-align: right;"> 17</td><td style="text-align: right;"> 88</td><td>[{&#x27;num_beneficiaries&#x27;: 151, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 288, &#x27;year&#x27;: 2019}, {&#x27;num_beneficia ...</td></tr>
# <tr><td style="text-align: right;"> 18</td><td style="text-align: right;">880</td><td>[{&#x27;num_beneficiaries&#x27;: 1093, &#x27;year&#x27;: 2020}, {&#x27;num_beneficiaries&#x27;: 1855, &#x27;year&#x27;: 2019}, {&#x27;num_benefic ...</td></tr>
# </tbody>
# </table>

# %%
try:
    supplier_cache = json.load(open('suppliers.cache.json'))
except Exception as e:
    print(e)
    supplier_cache = dict()

    
def check_entity_id():
    def func(rows):
        for row in rows:
            eid = row['entity_id']
            if eid and len(eid.strip())==9:
                yield row
                continue
            ERRORS.append(f'מספר ח.פ. לא תקין {eid}')
    return func


def fetch_supplier_data():
    global ERRORS
    global supplier_cache
    def func(rows):
        for row in rows:
            key = row['entity_id']
            if key not in supplier_cache:
                found = False
                resp = requests.get(f'https://next.obudget.org/search/entities?q={key}')
                if resp.status_code == 200:
                    resp = resp.json()['search_results']
                    if len(resp) > 0:
                        resp = resp[0]['source']
                        assert resp['id'] == key
                        kind = resp['kind']
                        resp = requests.get(f'https://next.obudget.org/get/org/{kind}/{key}')
                        if resp.status_code == 200:
                            supplier_cache[key] = resp.json()['value']
                            found = True
                if not found:
                    supplier_cache[key] = None
                    print(resp, key)
                print('GOT', len(supplier_cache))
            rec = supplier_cache[key]
            if rec:
                row['entity_kind'] = rec['kind']
                row['entity_kind_he'] = rec['kind_he']
                row['entity_name'] = rec['name']
                yield row
            else:
                ERRORS.append(f'לא נמצא מפעיל עם חפ {key}')                
    return DF.Flow(
        DF.add_field('entity_kind', 'string'),
        DF.add_field('entity_kind_he', 'string'),
        DF.add_field('entity_name', 'string'),
        DF.add_field('active', 'string', 'yes'),
        DF.add_field('related', 'string', 'yes'),
        func
    )


def suppliers():
    fields = ['catalog_number', 'entity_id', 'geo']
    return DF.Flow(
        loader(),
        DF.select_fields(fields),
        DF.set_type('geo', transform=lambda v: GEOS.get(v)),
        DF.join_with_self('activities', ['catalog_number', 'entity_id'], dict(
            catalog_number=None, entity_id=None, geo=dict(aggregate='set')
        )),
        DF.set_type('geo', type='array', transform=list),
        DF.set_type('entity_id', type='string', transform=str),
        check_entity_id(),
        fetch_supplier_data(),
        DF.add_field('suppliers', 'object', lambda r: dict((k, r[k]) for k in [
            'entity_id', 'entity_name', 'entity_kind', 'entity_kind_he', 'active', 'related', 'geo'
        ])),
        DF.join_with_self('activities', ['catalog_number'], dict(catalog_number=None, suppliers=dict(aggregate='array'))),
        DF.select_fields(['catalog_number', 'suppliers']),
#         DF.set_type('suppliers', type='object', transform=lambda v: dict(suppliers=v)),
        DF.printer(tablefmt='html'),
    ).results()[0][0]
   
items.extend(suppliers())

json.dump(supplier_cache, open('suppliers.cache.json', 'w'))
items
# Out:
# GOT 424
# GOT 425
# GOT 426
# GOT 427
# GOT 428
# GOT 429
# GOT 430
# GOT 431
# GOT 432
# GOT 433
# GOT 434
# GOT 435
# GOT 436
# GOT 437
# GOT 438
# GOT 439
# GOT 440
# GOT 441
# GOT 442
# GOT 443
# GOT 444
# GOT 445
# GOT 446
# GOT 447
# GOT 448
# GOT 449
# GOT 450
# GOT 451
# GOT 452
# GOT 453
# GOT 454
# GOT 455
# [] 557855210
# GOT 456
# GOT 457
# GOT 458
# GOT 459
# GOT 460
# GOT 461
# GOT 462
# GOT 463
# GOT 464
# GOT 465
# GOT 466
# GOT 467
# GOT 468
# GOT 469
# GOT 470
# GOT 471
# GOT 472
# GOT 473
# GOT 474
# GOT 475
# GOT 476
# GOT 477
# GOT 478
# [] 580005039
# GOT 479
# GOT 480
# GOT 481
# GOT 482
# GOT 483
# GOT 484
# GOT 485
# GOT 486
# GOT 487
# GOT 488
# GOT 489
# GOT 490
# [] 580060852
# GOT 491
# GOT 492
# GOT 493
# GOT 494
# GOT 495
# GOT 496
# GOT 497
# <h3>activities</h3>
# <table>
# <thead>
# <tr><th style="text-align: right;">  #</th><th style="text-align: right;">    catalog_number
# (integer)</th><th>suppliers
# (array)                                                                                                         </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  1</td><td style="text-align: right;"> 14</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;512676206&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;">  2</td><td style="text-align: right;">142</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;500701164&#x27;, &#x27;entity_kind&#x27;: &#x27;university&#x27;, &#x27;entity_kind_he&#x27;: &#x27;אוניברס ...</td></tr>
# <tr><td style="text-align: right;">  3</td><td style="text-align: right;">143</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;510913205&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;">  4</td><td style="text-align: right;">145</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;500301783&#x27;, &#x27;entity_kind&#x27;: &#x27;religion_service&#x27;, &#x27;entity_kind_he&#x27;: &#x27;ש ...</td></tr>
# <tr><td style="text-align: right;">  5</td><td style="text-align: right;">147</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;510525348&#x27;, &#x27;entity_kind&#x27;: &#x27;association&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חל&quot;צ&#x27;, ...</td></tr>
# <tr><td style="text-align: right;">  6</td><td style="text-align: right;">648</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;510355720&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;">  7</td><td style="text-align: right;">667</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;580019602&#x27;, &#x27;entity_kind&#x27;: &#x27;association&#x27;, &#x27;entity_kind_he&#x27;: &#x27;עמותה&#x27; ...</td></tr>
# <tr><td style="text-align: right;">  8</td><td style="text-align: right;">712</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;500301783&#x27;, &#x27;entity_kind&#x27;: &#x27;religion_service&#x27;, &#x27;entity_kind_he&#x27;: &#x27;ש ...</td></tr>
# <tr><td style="text-align: right;">  9</td><td style="text-align: right;">713</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;512641507&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;"> 10</td><td style="text-align: right;">714</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;511369720&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;"> 11</td><td style="text-align: right;"> 75</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;512593617&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;"> 12</td><td style="text-align: right;">786</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;510792575&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;"> 13</td><td style="text-align: right;"> 82</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;511370298&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;"> 14</td><td style="text-align: right;"> 84</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;511369720&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;"> 15</td><td style="text-align: right;"> 86</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;510525348&#x27;, &#x27;entity_kind&#x27;: &#x27;association&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חל&quot;צ&#x27;, ...</td></tr>
# <tr><td style="text-align: right;"> 16</td><td style="text-align: right;"> 87</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;510355720&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# <tr><td style="text-align: right;"> 17</td><td style="text-align: right;"> 88</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;580000271&#x27;, &#x27;entity_kind&#x27;: &#x27;association&#x27;, &#x27;entity_kind_he&#x27;: &#x27;עמותה&#x27; ...</td></tr>
# <tr><td style="text-align: right;"> 18</td><td style="text-align: right;">880</td><td>[{&#x27;active&#x27;: &#x27;yes&#x27;, &#x27;entity_id&#x27;: &#x27;511121014&#x27;, &#x27;entity_kind&#x27;: &#x27;company&#x27;, &#x27;entity_kind_he&#x27;: &#x27;חברה פרטית ...</td></tr>
# </tbody>
# </table>
# [{'catalog_number': 14,
#   'manualBudget': [{'approved': 7913073.16,
#     'executed': 7913073.16,
#     'year': 2020},
#    {'approved': 8982450.52, 'executed': 8982450.52, 'year': 2019},
#    {'approved': 9845896.7, 'executed': 9845896.7, 'year': 2018},
#    {'approved': 9382294.86, 'executed': 9382294.86, 'year': 2017}]},
#  {'catalog_number': 142,
#   'manualBudget': [{'approved': 211489092.88000003,
#     'executed': 211489092.88000003,
#     'year': 2020},
#    {'approved': 208092510.53000003,
#     'executed': 208092510.53000003,
#     'year': 2019},
#    {'approved': 175814697.69000003,
#     'executed': 175814697.69000003,
#     'year': 2018},
#    {'approved': 145600218.48999998,
#     'executed': 145600218.48999998,
#     'year': 2017}]},
#  {'catalog_number': 143,
#   'manualBudget': [{'approved': 354153830.7099999,
#     'executed': 354153830.7099999,
#     'year': 2020},
#    {'approved': 329942492.09999996,
#     'executed': 329942492.09999996,
#     'year': 2019},
#    {'approved': 324132686.6399998,
#     'executed': 324132686.6399998,
#     'year': 2018},
#    {'approved': 280611814.96, 'executed': 280611814.96, 'year': 2017}]},
#  {'catalog_number': 145,
#   'manualBudget': [{'approved': 20554148.87,
#     'executed': 20554148.87,
#     'year': 2020},
#    {'approved': 30711850.190000005,
#     'executed': 30711850.190000005,
#     'year': 2019},
#    {'approved': 24310564.88, 'executed': 24310564.88, 'year': 2018},
#    {'approved': 25550255, 'executed': 25550255, 'year': 2017}]},
#  {'catalog_number': 147,
#   'manualBudget': [{'approved': 824783.7, 'executed': 824783.7, 'year': 2020},
#    {'approved': 1607757.05, 'executed': 1607757.05, 'year': 2019},
#    {'approved': 1405878.3499999999,
#     'executed': 1405878.3499999999,
#     'year': 2018},
#    {'approved': 1294036.96, 'executed': 1294036.96, 'year': 2017}]},
#  {'catalog_number': 648,
#   'manualBudget': [{'approved': 14181149.750000002,
#     'executed': 14181149.750000002,
#     'year': 2020},
#    {'approved': 15752528.14, 'executed': 15752528.14, 'year': 2019},
#    {'approved': 16880622.1, 'executed': 16880622.1, 'year': 2018},
#    {'approved': 16514997.860000001,
#     'executed': 16514997.860000001,
#     'year': 2017}]},
#  {'catalog_number': 667,
#   'manualBudget': [{'approved': 577728.39,
#     'executed': 577728.39,
#     'year': 2020},
#    {'approved': 672644.51, 'executed': 672644.51, 'year': 2019},
#    {'approved': 334021.77, 'executed': 334021.77, 'year': 2018},
#    {'approved': 213517.86, 'executed': 213517.86, 'year': 2017}]},
#  {'catalog_number': 712,
#   'manualBudget': [{'approved': 1561394568.3699996,
#     'executed': 1561394568.3699996,
#     'year': 2020},
#    {'approved': 1455724396.6700003,
#     'executed': 1455724396.6700003,
#     'year': 2019},
#    {'approved': 1401433660.2799993,
#     'executed': 1401433660.2799993,
#     'year': 2018},
#    {'approved': 1298844083.0199997,
#     'executed': 1298844083.0199997,
#     'year': 2017}]},
#  {'catalog_number': 713,
#   'manualBudget': [{'approved': 35530534.88999999,
#     'executed': 35530534.88999999,
#     'year': 2020},
#    {'approved': 32095481.830000002,
#     'executed': 32095481.830000002,
#     'year': 2019},
#    {'approved': 29804308.910000004,
#     'executed': 29804308.910000004,
#     'year': 2018},
#    {'approved': 26797159.0, 'executed': 26797159.0, 'year': 2017}]},
#  {'catalog_number': 714,
#   'manualBudget': [{'approved': 74329981.05,
#     'executed': 74329981.05,
#     'year': 2020},
#    {'approved': 62762107.54000001,
#     'executed': 62762107.54000001,
#     'year': 2019},
#    {'approved': 56171850.760000005,
#     'executed': 56171850.760000005,
#     'year': 2018},
#    {'approved': 57508152.34, 'executed': 57508152.34, 'year': 2017}]},
#  {'catalog_number': 75,
#   'manualBudget': [{'approved': 6455537.73,
#     'executed': 6455537.73,
#     'year': 2020},
#    {'approved': 4349695.130000001,
#     'executed': 4349695.130000001,
#     'year': 2019},
#    {'approved': 7195368.739999999,
#     'executed': 7195368.739999999,
#     'year': 2018},
#    {'approved': 5751225.86, 'executed': 5751225.86, 'year': 2017}]},
#  {'catalog_number': 786,
#   'manualBudget': [{'approved': 585434172.5199999,
#     'executed': 585434172.5199999,
#     'year': 2020},
#    {'approved': 516199542.12999994,
#     'executed': 516199542.12999994,
#     'year': 2019},
#    {'approved': 472721360.7400002,
#     'executed': 472721360.7400002,
#     'year': 2018},
#    {'approved': 406906231.3199999,
#     'executed': 406906231.3199999,
#     'year': 2017}]},
#  {'catalog_number': 82,
#   'manualBudget': [{'approved': 57982264.41,
#     'executed': 57982264.41,
#     'year': 2020},
#    {'approved': 29591074.410000004,
#     'executed': 29591074.410000004,
#     'year': 2019},
#    {'approved': 4547190.319999999,
#     'executed': 4547190.319999999,
#     'year': 2018}]},
#  {'catalog_number': 84,
#   'manualBudget': [{'approved': 4219503.28,
#     'executed': 4219503.28,
#     'year': 2020},
#    {'approved': 7666073.649999999,
#     'executed': 7666073.649999999,
#     'year': 2019},
#    {'approved': 7119141.040000001,
#     'executed': 7119141.040000001,
#     'year': 2018},
#    {'approved': 6766586.11, 'executed': 6766586.11, 'year': 2017}]},
#  {'catalog_number': 86,
#   'manualBudget': [{'approved': 11520163.54,
#     'executed': 11520163.54,
#     'year': 2020},
#    {'approved': 11294779.23, 'executed': 11294779.23, 'year': 2019},
#    {'approved': 8534652.69, 'executed': 8534652.69, 'year': 2018},
#    {'approved': 5802596.7700000005,
#     'executed': 5802596.7700000005,
#     'year': 2017}]},
#  {'catalog_number': 87,
#   'manualBudget': [{'approved': 608183.6599999999,
#     'executed': 608183.6599999999,
#     'year': 2020},
#    {'approved': 642653.41, 'executed': 642653.41, 'year': 2019},
#    {'approved': 614922, 'executed': 614922, 'year': 2018},
#    {'approved': 320126.4, 'executed': 320126.4, 'year': 2017}]},
#  {'catalog_number': 88,
#   'manualBudget': [{'approved': 537020.24,
#     'executed': 537020.24,
#     'year': 2020},
#    {'approved': 530883.2599999999,
#     'executed': 530883.2599999999,
#     'year': 2019},
#    {'approved': 643977.4700000001,
#     'executed': 643977.4700000001,
#     'year': 2018},
#    {'approved': 760866.03, 'executed': 760866.03, 'year': 2017}]},
#  {'catalog_number': 880,
#   'manualBudget': [{'approved': 53385291.48,
#     'executed': 53385291.48,
#     'year': 2020},
#    {'approved': 48853147.09000001,
#     'executed': 48853147.09000001,
#     'year': 2019},
#    {'approved': 39751365.95999999,
#     'executed': 39751365.95999999,
#     'year': 2018},
#    {'approved': 35065537.629999995,
#     'executed': 35065537.629999995,
#     'year': 2017}]},
#  {'catalog_number': 14,
#   'beneficiaries': [{'num_beneficiaries': 2479, 'year': 2020},
#    {'num_beneficiaries': 2690, 'year': 2019},
#    {'num_beneficiaries': 2178, 'year': 2018},
#    {'num_beneficiaries': 2039, 'year': 2017}]},
#  {'catalog_number': 142,
#   'beneficiaries': [{'num_beneficiaries': 4142, 'year': 2020},
#    {'num_beneficiaries': 6887, 'year': 2019},
#    {'num_beneficiaries': 4043, 'year': 2018},
#    {'num_beneficiaries': 3710, 'year': 2017}]},
#  {'catalog_number': 143,
#   'beneficiaries': [{'num_beneficiaries': 2488, 'year': 2020},
#    {'num_beneficiaries': 4842, 'year': 2019},
#    {'num_beneficiaries': 2612, 'year': 2018},
#    {'num_beneficiaries': 2456, 'year': 2017}]},
#  {'catalog_number': 145,
#   'beneficiaries': [{'num_beneficiaries': 5033, 'year': 2020},
#    {'num_beneficiaries': 10880, 'year': 2019},
#    {'num_beneficiaries': 7140, 'year': 2018},
#    {'num_beneficiaries': 7820, 'year': 2017}]},
#  {'catalog_number': 147,
#   'beneficiaries': [{'num_beneficiaries': 985, 'year': 2020},
#    {'num_beneficiaries': 2038, 'year': 2019},
#    {'num_beneficiaries': 1818, 'year': 2018},
#    {'num_beneficiaries': 1729, 'year': 2017}]},
#  {'catalog_number': 648,
#   'beneficiaries': [{'num_beneficiaries': 1162, 'year': 2020},
#    {'num_beneficiaries': 1739, 'year': 2019},
#    {'num_beneficiaries': 980, 'year': 2018},
#    {'num_beneficiaries': 1065, 'year': 2017}]},
#  {'catalog_number': 667,
#   'beneficiaries': [{'num_beneficiaries': 115, 'year': 2020},
#    {'num_beneficiaries': 219, 'year': 2019},
#    {'num_beneficiaries': 115, 'year': 2018},
#    {'num_beneficiaries': 95, 'year': 2017}]},
#  {'catalog_number': 712,
#   'beneficiaries': [{'num_beneficiaries': 8491, 'year': 2020},
#    {'num_beneficiaries': 16707, 'year': 2019},
#    {'num_beneficiaries': 8931, 'year': 2018},
#    {'num_beneficiaries': 8432, 'year': 2017}]},
#  {'catalog_number': 713,
#   'beneficiaries': [{'num_beneficiaries': 238, 'year': 2020},
#    {'num_beneficiaries': 407, 'year': 2019},
#    {'num_beneficiaries': 219, 'year': 2018},
#    {'num_beneficiaries': 206, 'year': 2017}]},
#  {'catalog_number': 714,
#   'beneficiaries': [{'num_beneficiaries': 641, 'year': 2020},
#    {'num_beneficiaries': 1075, 'year': 2019},
#    {'num_beneficiaries': 645, 'year': 2018},
#    {'num_beneficiaries': 531, 'year': 2017}]},
#  {'catalog_number': 75,
#   'beneficiaries': [{'num_beneficiaries': 1499, 'year': 2020},
#    {'num_beneficiaries': 1326, 'year': 2019},
#    {'num_beneficiaries': 1836, 'year': 2018},
#    {'num_beneficiaries': 1531, 'year': 2017}]},
#  {'catalog_number': 786,
#   'beneficiaries': [{'num_beneficiaries': 4273, 'year': 2020},
#    {'num_beneficiaries': 8095, 'year': 2019},
#    {'num_beneficiaries': 4035, 'year': 2018},
#    {'num_beneficiaries': 3743, 'year': 2017}]},
#  {'catalog_number': 82,
#   'beneficiaries': [{'num_beneficiaries': 544, 'year': 2020},
#    {'num_beneficiaries': 651, 'year': 2019},
#    {'num_beneficiaries': 141, 'year': 2018}]},
#  {'catalog_number': 84,
#   'beneficiaries': [{'num_beneficiaries': 679, 'year': 2020},
#    {'num_beneficiaries': 834, 'year': 2019},
#    {'num_beneficiaries': 512, 'year': 2018},
#    {'num_beneficiaries': 515, 'year': 2017}]},
#  {'catalog_number': 86,
#   'beneficiaries': [{'num_beneficiaries': 711, 'year': 2020},
#    {'num_beneficiaries': 1199, 'year': 2019},
#    {'num_beneficiaries': 512, 'year': 2018},
#    {'num_beneficiaries': 406, 'year': 2017}]},
#  {'catalog_number': 87,
#   'beneficiaries': [{'num_beneficiaries': 68, 'year': 2020},
#    {'num_beneficiaries': 69, 'year': 2019},
#    {'num_beneficiaries': 33, 'year': 2018},
#    {'num_beneficiaries': 35, 'year': 2017}]},
#  {'catalog_number': 88,
#   'beneficiaries': [{'num_beneficiaries': 151, 'year': 2020},
#    {'num_beneficiaries': 288, 'year': 2019},
#    {'num_beneficiaries': 160, 'year': 2018},
#    {'num_beneficiaries': 183, 'year': 2017}]},
#  {'catalog_number': 880,
#   'beneficiaries': [{'num_beneficiaries': 1093, 'year': 2020},
#    {'num_beneficiaries': 1855, 'year': 2019},
#    {'num_beneficiaries': 882, 'year': 2018},
#    {'num_beneficiaries': 788, 'year': 2017}]},
#  {'catalog_number': 14,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '512676206',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'פמי פרימיום בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580056455',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלי"ע - ארגון לקידום ילדים עם עוורון או לקות ראיה (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580421626',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'יעדים לצפון מיסודה של קרן רש"י (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'}]},
#  {'catalog_number': 142,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '500701164',
#     'entity_kind': 'university',
#     'entity_kind_he': 'אוניברסיטה',
#     'entity_name': 'בית ספר המשפחה הקדושה',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511370298',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'רנד - חברה לרווחה נפשית למשפחה בע״מ',
#     'geo': ['tspvn', 'yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512493578',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'ט.ח. המרכז הרפואי הגליל בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512593617',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'א.ד.נ.מ. בע״מ',
#     'geo': ['tspvn', 'drvm', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512685892',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'אלראזי- פ.פ.ס. ריהאב בע״מ',
#     'geo': ['tspvn', 'drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513014795',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'חנן - נצרת שרותי בית ורווחה בע״מ',
#     'geo': ['tspvn', 'drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513683367',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מכללת א-שורוק בע״מ',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580003739',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מסגרת שמעיה (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580006005',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מיחא ירושלים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580008324',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מרכז מילמן (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580014322',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שיח סוד- מרכז חינוכי שיקומי לבעלי צרכים מיוחדים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580015881',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'בית חולים אלי"ן - מרכז לשיקום ילדים ונוער (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580016723',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מיח"א מחנכי ילדים חרשים חיפה והצפון (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580021087',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אגודת ידידי מרכז רפואי בני ציון FRIENDS OF BNAI-ZION MEDICAL CENTER (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580030153',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מיח"א מחנכי ילדים חרשים באר שבע (ע"ר)',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580030872',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'בית מיחא הראשון מיסודו של ד"ר עזרא קורין (1954) (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580040301',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלה - עזר לילד המיוחד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580056455',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלי"ע - ארגון לקידום ילדים עם עוורון או לקות ראיה (ע"ר)',
#     'geo': ['tspvn', 'yv-sh', 'drvm', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580060952',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלווין ישראל (ע"ר)',
#     'geo': ['tspvn', 'yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580064335',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלו"ט - אגודה לאומית לילדים ובוגרים עם אוטיזם (ע\'\'ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580071850',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'בית איזי שפירא - עמותת אבי (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580079978',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עזר מציון (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580107787',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צהר לטהר (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580115319',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צעד קדימה - עמותה לחינוך ושיקום באמצעות גישת החינוך המדריך - פטו (ע"ר)',
#     'geo': ['drvm', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580118032',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'פ.ש.ר - העמותה לפיתוח שירותי רווחה וחינוך (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580165249',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'ס.ו.ל.ם. - סיוע ועידוד לילדים מוגבלים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580173987',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שלוה - האגודה הישראלית לטיפול באנשים עם מוגבלויות ושילובם בחברה (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580183986',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותה לילדים בסיכון (ע"ר) (.ASSOCIATION CHILDREN AT RISK (R.A',
#     'geo': ['tspvn', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580188894',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צ\'יימס ישראל                                              (ע"ר)  CHIMES ISRAEL (',
#     'geo': ['yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580199289',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מרכז מריאן לגיל הרך והמשפחה (ע"ר)',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580210243',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שמע קולנו - מרכז ארצי שיקום והדרכה ללקויי שמיעה (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580237808',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מרכזי תמיכה משלבים מ.ת.מ. (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580242287',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'יחידה אזורית להתפתחות הילד בקרית-שמונה (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580245066',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת זוהור אלג\'ד (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580263184',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'טף לטף-טיפוח ופיתוח הילד (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580266971',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'פתחיה - מוסדות לחינוך מיוחד (ע"ר)',
#     'geo': ['yv-sh', 'drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580300747',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'תאגיד הבריאות ליד המרכז הרפואי שמיר (אסף הרופא) (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580301182',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'תאגיד הבריאות ליד המרכז הרפואי לגליל (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580301992',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': "קרן מחקרים ושירותי בריאות - שיבא (ע''ר)",
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580307130',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'תאגיד הבריאות ליד המרכז הרפואי זיו (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580323889',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת יחדיו באר-שבע והדרום (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580326239',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מש"י - מרכז שקום ילדים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580342871',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אוהל פרידה לאה (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580344414',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'פרח לצמוח במקום טוב (ע"ר)',
#     'geo': ['yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580354637',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עדי נגב- נחלת ערן (ע"ר)',
#     'geo': ['yv-sh', 'drvm'],
#     'related': 'yes'}]},
#  {'catalog_number': 143,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '510913205',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון רמת טבריה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511121014',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'שלו ובניו בע״מ',
#     'geo': ['tspvn', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511138786',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'החברה לפיתוח שרותים קהילתיים רחובות בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511281198',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית רעות - מרכז טיפול ורווחה בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511369720',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית אקשטיין- שירותי חינוך בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511582462',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בר דרור 91 בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511617284',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'ק.ב.ע. - חברה להקמה,הפעלה וניהול שירותי רווחה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511762916',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': '״קידר״ - ניהול שרותי רווחה בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511871865',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'הוסטל בית פלדמן בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511898025',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מערך דיור עפולה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511952855',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון נצרת בע״מ',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512237108',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'הוסטל בית אריה בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512401043',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית נחליאל דיור קהילתי בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512419573',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון אתגר בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512593617',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'א.ד.נ.מ. בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512674102',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעונות גל בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512674151',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעונות סלאם בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512996612',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון השלושה בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513488999',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית קאנא - מוסא עואודה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513726281',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'דיור בעמק בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '514756097',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון הבית בחולון בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '520037565',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'דנאל אדיר יהושע בעמ',
#     'geo': ['drvm', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580002335',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים חיפה, אגודה לקימום אנשים עם מוגבלות שכלית התפתחותית (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580008100',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים - אגודה לקימום אנשים עם מוגבלות שכלית סניף איזור חדרה והשומרון (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580024057',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלין- בית נועם (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580034924',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים ישראל הארגון הארצי לאנשים עם מוגבלות שכלית ולמשפחותיהם (ע"ר)',
#     'geo': ['tspvn', 'yv-sh', 'drvm', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580064335',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלו"ט - אגודה לאומית לילדים ובוגרים עם אוטיזם (ע\'\'ר)',
#     'geo': ['tspvn', 'yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580085140',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': '"אהל שרה" מרכז לחינוך ולשיקום הילד המיוחד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580102416',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'רבדים בגליל (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580107787',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צהר לטהר (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580134732',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'ידידי כפר עידוד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580243129',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': "עמיחי ע''ש עמיחי שולזינגר ז''ל (ע''ר)",
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580257145',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מרכז שיקום גראבסקי (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580308856',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': '"ברון יחד", עמותה',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580324408',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'סדנת שילוב - גבעות (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580345056',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת מרכז כוכב מעלות תרשיחא (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580421626',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'יעדים לצפון מיסודה של קרן רש"י (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'}]},
#  {'catalog_number': 145,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '500301783',
#     'entity_kind': 'religion_service',
#     'entity_kind_he': 'שירות דת',
#     'entity_name': 'הלב הקדוש',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '510084924',
#     'entity_kind': 'association',
#     'entity_kind_he': 'חל"צ',
#     'entity_name': 'חות הנוער הציוני ע״ש ד״ר ישראל גולדשטין בע״מ (חל״צ)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '510913205',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון רמת טבריה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '510945678',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעונות מרגוע פ. מ. בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '510983885',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון נוה כנרת בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511121014',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'שלו ובניו בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511263410',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'הוד - מעון פניימיתי לחינוך מיוחד בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511370298',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'רנד - חברה לרווחה נפשית למשפחה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511628984',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון דרור - ירכא בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511838922',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון רוגלית בע״מ',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511906349',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'הוסטל רמת טבריה 1993 בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511946261',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'ק.ש.ר. קידום שרותים חברתיים בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511952855',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון נצרת בע״מ',
#     'geo': ['tspvn', 'yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512076613',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'אלבסמה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512094202',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון ״אל-נהדה״ לנכים ולנזקקים בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512108911',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מוסד בית אלחנאן בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512330804',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית עזרה עדן בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512335019',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'יאסמין (ביתינו) בע״מ',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512593617',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'א.ד.נ.מ. בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512674102',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעונות גל בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512674151',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעונות סלאם בע״מ',
#     'geo': ['tspvn', 'drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513297457',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון נוה רם בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513488999',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית קאנא - מוסא עואודה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '514633106',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעון עדנאן עטאללה ובניו בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '520037565',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'דנאל אדיר יהושע בעמ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '570000364',
#     'entity_kind': 'cooperative',
#     'entity_kind_he': 'אגודה שיתופית',
#     'entity_name': 'קיבוץ בית אלפא',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580003739',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מסגרת שמעיה (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580006039',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'המרכז לעיוור בישראל (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580008100',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים - אגודה לקימום אנשים עם מוגבלות שכלית סניף איזור חדרה והשומרון (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580014322',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שיח סוד- מרכז חינוכי שיקומי לבעלי צרכים מיוחדים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580023992',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'בית הגלגלים (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580024057',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלין- בית נועם (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580034924',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים ישראל הארגון הארצי לאנשים עם מוגבלות שכלית ולמשפחותיהם (ע"ר)',
#     'geo': ['yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580036242',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'איל"ן אגוד ישראלי לילדים נפגעים (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580038057',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'גן הילד חיפה, אגודה לניהול גן משחקים לילדים מוגבלים - גמל"ם (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580038545',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מכון בית דוד (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580040301',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלה - עזר לילד המיוחד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580044980',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'ישיבת ההסדר קרני שומרון (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580064335',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלו"ט - אגודה לאומית לילדים ובוגרים עם אוטיזם (ע\'\'ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580064970',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'העמותה להפעלת מערך דיור מעוני כפר כנא (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580079978',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עזר מציון (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580085140',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': '"אהל שרה" מרכז לחינוך ולשיקום הילד המיוחד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580094381',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלה - מוריה (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580096709',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אגודת רפואה וחיים ויזניץ, בנשיאות כבוד האדמו"ר שליט"א (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580107787',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צהר לטהר (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580115319',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צעד קדימה - עמותה לחינוך ושיקום באמצעות גישת החינוך המדריך - פטו (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580150043',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'רפואה וישועה - אגודת ביקור חולים דחסידי גור בארץ ישראל (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580156669',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'רחשי לב (ע"ר)',
#     'geo': ['yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580172831',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלי שיח (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580173987',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שלוה - האגודה הישראלית לטיפול באנשים עם מוגבלויות ושילובם בחברה (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580175677',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'קו לחיים - תנועה חברתית לשיפור והצלת חיים בישראל (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580217370',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': '"בני שמחה"',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580227353',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'להאיר את העיר (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580243129',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': "עמיחי ע''ש עמיחי שולזינגר ז''ל (ע''ר)",
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580265155',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עדי ירושלים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580333011',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'לב בנימין (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580345056',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת מרכז כוכב מעלות תרשיחא (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580345726',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אוהל אשר (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580354637',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עדי נגב- נחלת ערן (ע"ר)',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580356939',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'הקו המאחד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
# ...
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580014322',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שיח סוד- מרכז חינוכי שיקומי לבעלי צרכים מיוחדים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580015519',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים - אגודה לקידום אנשים עם מוגבלויות - ירושלים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580020287',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שק"ל - שילוב קהילתי לאנשים עם מוגבלויות (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580029528',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שדה חמד כפר נוער חקלאי של הס\' אגודת ישראל בא"י (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580036028',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אגודת עמי - עמותה לטיפול באדם עם מוגבלות שכלית התפתחותית (ע"ר)',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580036242',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'איל"ן אגוד ישראלי לילדים נפגעים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580052074',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': '"ניצן" - רחובות, אגודה לקידום ילדים ובוגרים לקויי למידה, הסתגלות ותפקוד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580058808',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'ניצן - המרכז הארצי, אגודה לקידום ילדים ובוגרים לקויי למידה, הסתגלות ותיפקוד. (ע"',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580060952',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלווין ישראל (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580065795',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': '"ניצן" אגודה לקידום ילדים לקויי למידה והסתגלות (חיפה) (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580107787',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צהר לטהר (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580157840',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'יחד בגליל (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580163830',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מכון פוירשטיין (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580172831',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלי שיח (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580216703',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'קמ"ה - קהילה מרפאת בהרדוף (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580240919',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת גוונים לפיתוח החינוך הקהילה והסביבה (ע"ר)',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580323889',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת יחדיו באר-שבע והדרום (ע"ר)',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580324408',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'סדנת שילוב - גבעות (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580345726',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אוהל אשר (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'}]},
#  {'catalog_number': 82,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '511370298',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'רנד - חברה לרווחה נפשית למשפחה בע״מ',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511898025',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מערך דיור עפולה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512593617',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'א.ד.נ.מ. בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512674102',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'מעונות גל בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513488999',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית קאנא - מוסא עואודה בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580008100',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים - אגודה לקימום אנשים עם מוגבלות שכלית סניף איזור חדרה והשומרון (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580014322',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שיח סוד- מרכז חינוכי שיקומי לבעלי צרכים מיוחדים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580016103',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אגודה לבריאות הציבור (ע"ר)',
#     'geo': ['drvm'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580044980',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'ישיבת ההסדר קרני שומרון (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580058808',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'ניצן - המרכז הארצי, אגודה לקידום ילדים ובוגרים לקויי למידה, הסתגלות ותיפקוד. (ע"',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580060952',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלווין ישראל (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580085140',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': '"אהל שרה" מרכז לחינוך ולשיקום הילד המיוחד (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580094381',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלה - מוריה (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580172831',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלי שיח (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580173987',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שלוה - האגודה הישראלית לטיפול באנשים עם מוגבלויות ושילובם בחברה (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580333011',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'לב בנימין (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580345726',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אוהל אשר (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580409761',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת כוכב הצפון (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580438026',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'יד לילד המיוחד (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'}]},
#  {'catalog_number': 84,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '511369720',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית אקשטיין- שירותי חינוך בע״מ',
#     'geo': ['tspvn', 'yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513474809',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'א.ח. אשנב בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580000271',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'האגודה למען העוור הרצליה והשרון ע"ש מרים מוזס (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580421626',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'יעדים לצפון מיסודה של קרן רש"י (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580532240',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אבני דרך לחיים (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'}]},
#  {'catalog_number': 86,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '510525348',
#     'entity_kind': 'association',
#     'entity_kind_he': 'חל"צ',
#     'entity_name': 'החברה למתנ״סים - מרכזים קהילתיים בישראל בע״מ (חל״צ)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '513737205',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'ב.מ. פת״מ - פתרונות תעסוקתיים מתקדמים בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '514058825',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'אקולוגיה לקהילה מוגנת בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580008100',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים - אגודה לקימום אנשים עם מוגבלות שכלית סניף איזור חדרה והשומרון (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580020287',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שק"ל - שילוב קהילתי לאנשים עם מוגבלויות (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580034924',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אקים ישראל הארגון הארצי לאנשים עם מוגבלות שכלית ולמשפחותיהם (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'}]},
#  {'catalog_number': 87,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '510355720',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'חב המשקם לתעסוקת קשישים ובעלי כושר עבודה מוגבל בעמ',
#     'geo': ['mrkz'],
#     'related': 'yes'}]},
#  {'catalog_number': 88,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '580000271',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'האגודה למען העוור הרצליה והשרון ע"ש מרים מוזס (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580018851',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'האגודה למען העיוור, נפת רחובות (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580019214',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותה למען העיוור ומניעת עיוורון ירושלים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580023398',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אגודת החרשים בישראל (ע"ר)',
#     'geo': ['tspvn', 'yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580028173',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'האגודה למען העוור ולמניעת העוורון חיפה (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'}]},
#  {'catalog_number': 880,
#   'suppliers': [{'active': 'yes',
#     'entity_id': '511121014',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'שלו ובניו בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511369720',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'בית אקשטיין- שירותי חינוך בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '511617284',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'ק.ב.ע. - חברה להקמה,הפעלה וניהול שירותי רווחה בע״מ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '512593617',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'א.ד.נ.מ. בע״מ',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '520037565',
#     'entity_kind': 'company',
#     'entity_kind_he': 'חברה פרטית',
#     'entity_name': 'דנאל אדיר יהושע בעמ',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580014322',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שיח סוד- מרכז חינוכי שיקומי לבעלי צרכים מיוחדים (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580020287',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'שק"ל - שילוב קהילתי לאנשים עם מוגבלויות (ע"ר)',
#     'geo': ['yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580023992',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'בית הגלגלים (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580036242',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'איל"ן אגוד ישראלי לילדים נפגעים (ע"ר)',
#     'geo': ['tspvn', 'drvm', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580064335',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אלו"ט - אגודה לאומית לילדים ובוגרים עם אוטיזם (ע\'\'ר)',
#     'geo': ['tspvn', 'yv-sh', 'drvm', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580079978',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עזר מציון (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580115319',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'צעד קדימה - עמותה לחינוך ושיקום באמצעות גישת החינוך המדריך - פטו (ע"ר)',
#     'geo': ['yv-sh', 'mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580163830',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'מכון פוירשטיין (ע"ר)',
#     'geo': ['mrkz'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580172831',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עלי שיח (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580409761',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'עמותת כוכב הצפון (ע"ר)',
#     'geo': ['tspvn'],
#     'related': 'yes'},
#    {'active': 'yes',
#     'entity_id': '580427821',
#     'entity_kind': 'association',
#     'entity_kind_he': 'עמותה',
#     'entity_name': 'אבוקת אור (ע"ר)',
#     'geo': ['yv-sh'],
#     'related': 'yes'}]}]

# %%
try:
    budget_cache = json.load(open('budget_items.cache.json'))
except Exception as e:
    print(e)
    budget_cache = dict()

def fix_budget_code(b, row):
    b = str(b)
    b = b[:-1]
    assert len(b) <= 6
    while len(b) < 6:
        b = '0' + b
    b = '0023' + b
    return b

def fetch_budget_data():
    global ERRORS
    global budget_cache
    def func(rows):
        for row in rows:
            year = row['year']
            code = row['code']
            key = '{}/{}'.format(code, year)
            if key not in budget_cache:
                resp = requests.get(f'https://next.obudget.org/get/budget/{code}/{year}')
                if resp.status_code == 200:
                    budget_cache[key] = resp.json()['value']
                else:
                    budget_cache[key] = None
                    print(resp, key)
                print('GOT', len(budget_cache))
            rec = budget_cache[key]
            if rec:
                row['title'] = rec['title']
                yield row
            else:
                code = code[2:]
                ERRORS.append(f'לא נמצאה תקנה {code} בשנה {year}')
    return DF.Flow(
        DF.add_field('title', 'string'),
        func
    )

def budget_codes():
    fields = ['catalog_number', 'year', 'code']
    return DF.Flow(
        loader(),
        DF.select_fields(fields),
        DF.join_with_self('activities', fields, dict((f, None) for f in fields)),
        DF.set_type('code', type='string', transform=fix_budget_code),
        fetch_budget_data(),
        DF.add_field('budgetItems', 'object', lambda r: dict((k, r[k]) for k in ['code', 'title', 'year'])),
        DF.join_with_self('activities', ['catalog_number'], dict(catalog_number=None, budgetItems=dict(aggregate='array'))),
        DF.select_fields(['catalog_number', 'budgetItems']),
        DF.set_type('budgetItems', transform=lambda v: sorted(v, key=lambda i: i['year'], reverse=True)),
#         DF.set_type('budgetItems', type='object', transform=lambda v: dict(budgetItems=v)),
        DF.printer(tablefmt='html'),
    ).results()[0][0]
        
items.extend(budget_codes())

json.dump(budget_cache, open('budget_items.cache.json', 'w'))
# Out:
# <Response [404]> 0023072202/2017
# GOT 213
# GOT 214
# <Response [404]> 0023072206/2018
# GOT 215
# GOT 216
# <Response [404]> 0023072206/2019
# GOT 217
# GOT 218
# GOT 219
# GOT 220
# GOT 221
# GOT 222
# GOT 223
# <Response [404]> 0023072271/2018
# GOT 224
# GOT 225
# <Response [404]> 0023072271/2019
# GOT 226
# GOT 227
# GOT 228
# <Response [404]> 0023072204/2017
# GOT 229
# GOT 230
# GOT 231
# <Response [404]> 0023072204/2018
# GOT 232
# GOT 233
# GOT 234
# GOT 235
# GOT 236
# <Response [404]> 0023072203/2018
# GOT 237
# GOT 238
# GOT 239
# <Response [404]> 0023072203/2019
# GOT 240
# GOT 241
# GOT 242
# GOT 243
# <h3>activities</h3>
# <table>
# <thead>
# <tr><th style="text-align: right;">  #</th><th style="text-align: right;">    catalog_number
# (integer)</th><th>budgetItems
# (array)                                                                                                         </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  1</td><td style="text-align: right;"> 14</td><td>[{&#x27;code&#x27;: &#x27;0023072271&#x27;, &#x27;title&#x27;: &#x27;אבזור וסיוע לעיוורים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023062266&#x27;, &#x27;titl ...</td></tr>
# <tr><td style="text-align: right;">  2</td><td style="text-align: right;">142</td><td>[{&#x27;code&#x27;: &#x27;0023072202&#x27;, &#x27;title&#x27;: &#x27;מעונות יום שיקומיים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023103841&#x27;, &#x27;title ...</td></tr>
# <tr><td style="text-align: right;">  3</td><td style="text-align: right;">143</td><td>[{&#x27;code&#x27;: &#x27;0023072101&#x27;, &#x27;title&#x27;: &#x27;מסגרות דיור לנכים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072102&#x27;, &#x27;title&#x27;: ...</td></tr>
# <tr><td style="text-align: right;">  4</td><td style="text-align: right;">145</td><td>[{&#x27;code&#x27;: &#x27;0023072206&#x27;, &#x27;title&#x27;: &#x27;נופשונים מוגבלויות&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072206&#x27;, &#x27;title&#x27; ...</td></tr>
# <tr><td style="text-align: right;">  5</td><td style="text-align: right;">147</td><td>[{&#x27;code&#x27;: &#x27;0023012021&#x27;, &#x27;title&#x27;: &#x27;התמודדות עם מצבי חירום&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072201&#x27;, &#x27;ti ...</td></tr>
# <tr><td style="text-align: right;">  6</td><td style="text-align: right;">648</td><td>[{&#x27;code&#x27;: &#x27;0023072204&#x27;, &#x27;title&#x27;: &#x27;מעונות יום ומפעלי&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072221&#x27;, &#x27;title&#x27;: ...</td></tr>
# <tr><td style="text-align: right;">  7</td><td style="text-align: right;">667</td><td>[{&#x27;code&#x27;: &#x27;0023072201&#x27;, &#x27;title&#x27;: &#x27;שירותי קהילה לילדים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072203&#x27;, &#x27;title ...</td></tr>
# <tr><td style="text-align: right;">  8</td><td style="text-align: right;">712</td><td>[{&#x27;code&#x27;: &#x27;0023103841&#x27;, &#x27;title&#x27;: &#x27;פנימיות ילד ונער&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023116560&#x27;, &#x27;title&#x27;:  ...</td></tr>
# <tr><td style="text-align: right;">  9</td><td style="text-align: right;">713</td><td>[{&#x27;code&#x27;: &#x27;0023103841&#x27;, &#x27;title&#x27;: &#x27;פנימיות ילד ונער&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072101&#x27;, &#x27;title&#x27;:  ...</td></tr>
# <tr><td style="text-align: right;"> 10</td><td style="text-align: right;">714</td><td>[{&#x27;code&#x27;: &#x27;0023072101&#x27;, &#x27;title&#x27;: &#x27;מסגרות דיור לנכים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072101&#x27;, &#x27;title&#x27;: ...</td></tr>
# <tr><td style="text-align: right;"> 11</td><td style="text-align: right;"> 75</td><td>[{&#x27;code&#x27;: &#x27;0023072204&#x27;, &#x27;title&#x27;: &#x27;מעונות יום ומפעלי&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072222&#x27;, &#x27;title&#x27;: ...</td></tr>
# <tr><td style="text-align: right;"> 12</td><td style="text-align: right;">786</td><td>[{&#x27;code&#x27;: &#x27;0023072101&#x27;, &#x27;title&#x27;: &#x27;מסגרות דיור לנכים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072102&#x27;, &#x27;title&#x27;: ...</td></tr>
# <tr><td style="text-align: right;"> 13</td><td style="text-align: right;"> 82</td><td>[{&#x27;code&#x27;: &#x27;0023072101&#x27;, &#x27;title&#x27;: &#x27;מסגרות דיור לנכים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072102&#x27;, &#x27;title&#x27;: ...</td></tr>
# <tr><td style="text-align: right;"> 14</td><td style="text-align: right;"> 84</td><td>[{&#x27;code&#x27;: &#x27;0023072222&#x27;, &#x27;title&#x27;: &#x27;מסגרות יום לבוגרים עם&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072222&#x27;, &#x27;tit ...</td></tr>
# <tr><td style="text-align: right;"> 15</td><td style="text-align: right;"> 86</td><td>[{&#x27;code&#x27;: &#x27;0023072204&#x27;, &#x27;title&#x27;: &#x27;מעונות יום ומפעלי&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072221&#x27;, &#x27;title&#x27;: ...</td></tr>
# <tr><td style="text-align: right;"> 16</td><td style="text-align: right;"> 87</td><td>[{&#x27;code&#x27;: &#x27;0023072221&#x27;, &#x27;title&#x27;: &#x27;שירותי קהילה לבוגרים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072222&#x27;, &#x27;titl ...</td></tr>
# <tr><td style="text-align: right;"> 17</td><td style="text-align: right;"> 88</td><td>[{&#x27;code&#x27;: &#x27;0023072221&#x27;, &#x27;title&#x27;: &#x27;שירותי קהילה לבוגרים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072221&#x27;, &#x27;titl ...</td></tr>
# <tr><td style="text-align: right;"> 18</td><td style="text-align: right;">880</td><td>[{&#x27;code&#x27;: &#x27;0023072201&#x27;, &#x27;title&#x27;: &#x27;שירותי קהילה לילדים&#x27;, &#x27;year&#x27;: 2020}, {&#x27;code&#x27;: &#x27;0023072204&#x27;, &#x27;title ...</td></tr>
# </tbody>
# </table>

# %%
try:
    tender_cache = json.load(open('tenders.cache.json'))
except Exception as e:
    print(e)
    tender_cache = dict()

FF = ['tender_id', 'tender_key', 'tender_type', 'tender_type_he',
      'publication_id', 'decision', 'description', 'page_url', 
      'publisher', 'regulation']
    
def fetch_tender_data():
    global ERRORS
    global tender_cache
    def func(rows):
        for row in rows:
            keys = [row['tender']]
            parts = row['tender'].split('/')
            keys.append('{}-{}'.format(*parts))
            keys.append('{}/20{}'.format(*parts))
            keys.append('{}-20{}'.format(*parts))
            found = False
            found_key = None
            for key in keys:
                found = False
                if key not in tender_cache:
                    params = dict(
                        size=10, offset=0, q=key, from_date='1900-01-01', to_date='2100-01-01',
                        filter='[{"publisher":"הרווחה"}]'
                    )
                    resp = requests.get('https://next.obudget.org/search/tenders', params=params)
                    if resp.status_code == 200:
                        resp = resp.json()['search_results']
                        if len(resp) > 0:
                            for result in resp:
                                result = result['source']
                                if result['tender_id'] != key:
                                    continue
                                print('FOUND', key)
                                pid = result['publication_id']
                                tt = result['tender_type']
                                resp = requests.get(f'https://next.obudget.org/get/tenders/{tt}/{pid}/{key}')
                                if resp.status_code == 200:
                                    tender_cache[key] = resp.json()['value']
                                    break
                if tender_cache.get(key) is not None:
                    found = True
                    found_key = key
                if not found:
                    tender_cache[key] = None
                if found_key:
                    break
            print('GOT', len(tender_cache), found_key, keys)
            if found_key:
                rec = tender_cache[found_key]
                rec['tender_key'] = '{publication_id}:{tender_type}:{tender_id}'.format(**rec)
                if rec:
                    for f in FF:
                        row[f] = rec[f]
                    yield row
            else:
                ERRORS.append('לא נמצא מכרז עם מזהה {} בשירות {}'.format(row['tender'], social_services[str(row['catalog_number'])]))
    return DF.Flow(
        *[
            DF.add_field(f, 'string') for f in FF
        ],
        DF.add_field('related', 'string', 'yes'),
        func
    )
    
def tenders():
    fields = ['catalog_number', 'tender']
    return DF.Flow(
        loader(),
        DF.select_fields(fields),
        DF.join_with_self('activities', fields, dict((f, None) for f in fields)),
        DF.filter_rows(lambda r: r['tender'] is not None),
        DF.set_type('tender', type='string'),
        fetch_tender_data(),
        DF.add_field('tenders', 'object', lambda r: dict((k, r[k]) for k in FF + ['related'])),
        DF.join_with_self('activities', ['catalog_number'], dict(catalog_number=None, tenders=dict(aggregate='array'))),
        DF.select_fields(['catalog_number', 'tenders']),
#         DF.set_type('tenders', type='object', transform=lambda v: dict(tenders=v)),
        DF.printer(tablefmt='html'),
    ).results()[0][0]
        
items.extend(tenders())

json.dump(tender_cache, open('tenders.cache.json', 'w'))
# Out:
# GOT 320 None ['112/15', '112-15', '112/2015', '112-2015']
# GOT 320 None ['113/15', '113-15', '113/2015', '113-2015']
# GOT 320 None ['114/15', '114-15', '114/2015', '114-2015']
# FOUND 136-2015
# GOT 324 136-2015 ['136/15', '136-15', '136/2015', '136-2015']
# GOT 328 None ['139/18', '139-18', '139/2018', '139-2018']
# GOT 332 None ['160/16', '160-16', '160/2016', '160-2016']
# GOT 336 None ['169/14', '169-14', '169/2014', '169-2014']
# GOT 340 None ['170/14', '170-14', '170/2014', '170-2014']
# GOT 344 None ['170/15', '170-15', '170/2015', '170-2015']
# GOT 348 None ['171/14', '171-14', '171/2014', '171-2014']
# GOT 352 None ['172/14', '172-14', '172/2014', '172-2014']
# GOT 356 None ['184/15', '184-15', '184/2015', '184-2015']
# GOT 360 None ['237/17', '237-17', '237/2017', '237-2017']
# GOT 364 None ['263/16', '263-16', '263/2016', '263-2016']
# GOT 368 None ['264/16', '264-16', '264/2016', '264-2016']
# GOT 368 108-2015 ['108/15', '108-15', '108/2015', '108-2015']
# GOT 368 143/2012 ['143/12', '143-12', '143/2012', '143-2012']
# GOT 368 154/2012 ['154/12', '154-12', '154/2012', '154-2012']
# GOT 368 None ['154/14', '154-14', '154/2014', '154-2014']
# GOT 368 157/2015 ['157/15', '157-15', '157/2015', '157-2015']
# GOT 368 205/2016 ['205/16', '205-16', '205/2016', '205-2016']
# GOT 368 222-2014 ['222/14', '222-14', '222/2014', '222-2014']
# GOT 368 248/2016 ['248/16', '248-16', '248/2016', '248-2016']
# GOT 368 252/2017 ['252/17', '252-17', '252/2017', '252-2017']
# FOUND 105/2016
# GOT 371 105/2016 ['105/16', '105-16', '105/2016', '105-2016']
# FOUND 127/2017
# GOT 374 127/2017 ['127/17', '127-17', '127/2017', '127-2017']
# FOUND 136/2012
# GOT 377 136/2012 ['136/12', '136-12', '136/2012', '136-2012']
# FOUND 142/2012
# GOT 380 142/2012 ['142/12', '142-12', '142/2012', '142-2012']
# FOUND 142/2014
# GOT 383 142/2014 ['142/14', '142-14', '142/2014', '142-2014']
# FOUND 142/2018
# GOT 386 142/2018 ['142/18', '142-18', '142/2018', '142-2018']
# FOUND 144/2010
# GOT 389 144/2010 ['144/10', '144-10', '144/2010', '144-2010']
# FOUND 210/2014
# GOT 392 210/2014 ['210/14', '210-14', '210/2014', '210-2014']
# FOUND 230/2017
# GOT 395 230/2017 ['230/17', '230-17', '230/2017', '230-2017']
# FOUND 270/2011
# GOT 398 270/2011 ['270/11', '270-11', '270/2011', '270-2011']
# FOUND 300/2011
# GOT 401 300/2011 ['300/11', '300-11', '300/2011', '300-2011']
# FOUND 305/2017
# GOT 404 305/2017 ['305/17', '305-17', '305/2017', '305-2017']
# FOUND 102/2012
# GOT 407 102/2012 ['102/12', '102-12', '102/2012', '102-2012']
# GOT 407 230/2017 ['230/17', '230-17', '230/2017', '230-2017']
# FOUND 250/2016
# GOT 410 250/2016 ['250/16', '250-16', '250/2016', '250-2016']
# FOUND 126/2013
# GOT 413 126/2013 ['126/13', '126-13', '126/2013', '126-2013']
# FOUND 151/2015
# GOT 416 151/2015 ['151/15', '151-15', '151/2015', '151-2015']
# FOUND 162/2019
# GOT 419 162/2019 ['162/19', '162-19', '162/2019', '162-2019']
# FOUND 166/2015
# GOT 422 166/2015 ['166/15', '166-15', '166/2015', '166-2015']
# FOUND 188/2013
# GOT 425 188/2013 ['188/13', '188-13', '188/2013', '188-2013']
# FOUND 221/2014
# GOT 428 221/2014 ['221/14', '221-14', '221/2014', '221-2014']
# GOT 428 114/2010 ['114/10', '114-10', '114/2010', '114-2010']
# FOUND 123/2013
# GOT 431 123/2013 ['123/13', '123-13', '123/2013', '123-2013']
# GOT 431 142/2012 ['142/12', '142-12', '142/2012', '142-2012']
# FOUND 176/2011
# GOT 434 176/2011 ['176/11', '176-11', '176/2011', '176-2011']
# GOT 438 None ['284/17', '284-17', '284/2017', '284-2017']
# GOT 438 108-2015 ['108/15', '108-15', '108/2015', '108-2015']
# GOT 438 119/2010 ['119/10', '119-10', '119/2010', '119-2010']
# GOT 438 None ['126/07', '126-07', '126/2007', '126-2007']
# GOT 438 126/2017 ['126/17', '126-17', '126/2017', '126-2017']
# GOT 438 128/2016 ['128/16', '128-16', '128/2016', '128-2016']
# GOT 438 137/2014 ['137/14', '137-14', '137/2014', '137-2014']
# GOT 438 138/2014 ['138/14', '138-14', '138/2014', '138-2014']
# GOT 438 147/2011 ['147/11', '147-11', '147/2011', '147-2011']
# GOT 438 148/2013 ['148/13', '148-13', '148/2013', '148-2013']
# GOT 438 154/2012 ['154/12', '154-12', '154/2012', '154-2012']
# GOT 438 164/2009 ['164/09', '164-09', '164/2009', '164-2009']
# GOT 438 180/2013 ['180/13', '180-13', '180/2013', '180-2013']
# GOT 438 192/2016 ['192/16', '192-16', '192/2016', '192-2016']
# GOT 438 196/2018 ['196/18', '196-18', '196/2018', '196-2018']
# GOT 438 205/2016 ['205/16', '205-16', '205/2016', '205-2016']
# GOT 438 206/2016 ['206/16', '206-16', '206/2016', '206-2016']
# GOT 438 219/2013 ['219/13', '219-13', '219/2013', '219-2013']
# GOT 438 229/2013 ['229/13', '229-13', '229/2013', '229-2013']
# GOT 438 252/2017 ['252/17', '252-17', '252/2017', '252-2017']
# GOT 438 None ['255/15', '255-15', '255/2015', '255-2015']
# GOT 438 306/2017 ['306/17', '306-17', '306/2017', '306-2017']
# GOT 438 108-2015 ['108/15', '108-15', '108/2015', '108-2015']
# GOT 438 154/2012 ['154/12', '154-12', '154/2012', '154-2012']
# GOT 438 108-2015 ['108/15', '108-15', '108/2015', '108-2015']
# GOT 438 114/2016 ['114/16', '114-16', '114/2016', '114-2016']
# GOT 438 122/2012 ['122/12', '122-12', '122/2012', '122-2012']
# GOT 438 144/2014 ['144/14', '144-14', '144/2014', '144-2014']
# GOT 438 154/2012 ['154/12', '154-12', '154/2012', '154-2012']
# FOUND 177/2016
# GOT 441 177/2016 ['177/16', '177-16', '177/2016', '177-2016']
# FOUND 215-2014
# GOT 445 215-2014 ['215/14', '215-14', '215/2014', '215-2014']
# FOUND 253/2017
# GOT 448 253/2017 ['253/17', '253-17', '253/2017', '253-2017']
# FOUND 277/2017
# GOT 451 277/2017 ['277/17', '277-17', '277/2017', '277-2017']
# GOT 451 278/2017 ['278/17', '278-17', '278/2017', '278-2017']
# FOUND 116/2016
# GOT 454 116/2016 ['116/16', '116-16', '116/2016', '116-2016']
# FOUND 131/2019
# GOT 457 131/2019 ['131/19', '131-19', '131/2019', '131-2019']
# GOT 461 None ['140/10', '140-10', '140/2010', '140-2010']
# FOUND 173/2013
# GOT 464 173/2013 ['173/13', '173-13', '173/2013', '173-2013']
# GOT 464 104-2015 ['104/15', '104-15', '104/2015', '104-2015']
# GOT 464 108/2010 ['108/10', '108-10', '108/2010', '108-2010']
# GOT 464 108-2015 ['108/15', '108-15', '108/2015', '108-2015']
# GOT 464 119/2016 ['119/16', '119-16', '119/2016', '119-2016']
# GOT 464 None ['136/07', '136-07', '136/2007', '136-2007']
# GOT 464 137/2014 ['137/14', '137-14', '137/2014', '137-2014']
# GOT 464 None ['140/11', '140-11', '140/2011', '140-2011']
# GOT 464 147/2012 ['147/12', '147-12', '147/2012', '147-2012']
# GOT 464 152/2016 ['152/16', '152-16', '152/2016', '152-2016']
# GOT 464 154/2012 ['154/12', '154-12', '154/2012', '154-2012']
# GOT 464 222-2014 ['222/14', '222-14', '222/2014', '222-2014']
# GOT 464 252/2016 ['252/16', '252-16', '252/2016', '252-2016']
# GOT 464 252/2017 ['252/17', '252-17', '252/2017', '252-2017']
# GOT 464 122/2017 ['122/17', '122-17', '122/2017', '122-2017']
# GOT 464 157/2015 ['157/15', '157-15', '157/2015', '157-2015']
# FOUND 159/2012
# GOT 467 159/2012 ['159/12', '159-12', '159/2012', '159-2012']
# FOUND 162/2015
# GOT 470 162/2015 ['162/15', '162-15', '162/2015', '162-2015']
# FOUND 187/2018
# GOT 473 187/2018 ['187/18', '187-18', '187/2018', '187-2018']
# GOT 477 None ['120/13', '120-13', '120/2013', '120-2013']
# FOUND 129/2016
# GOT 480 129/2016 ['129/16', '129-16', '129/2016', '129-2016']
# GOT 480 101/2013 ['101/13', '101-13', '101/2013', '101-2013']
# GOT 484 None ['115/15', '115-15', '115/2015', '115-2015']
# GOT 488 None ['116/15', '116-15', '116/2015', '116-2015']
# GOT 492 None ['119/15', '119-15', '119/2015', '119-2015']
# GOT 496 None ['121/15', '121-15', '121/2015', '121-2015']
# GOT 500 None ['122/15', '122-15', '122/2015', '122-2015']
# GOT 504 None ['125/15', '125-15', '125/2015', '125-2015']
# GOT 508 None ['126/15', '126-15', '126/2015', '126-2015']
# GOT 512 None ['130/15', '130-15', '130/2015', '130-2015']
# GOT 516 None ['143/15', '143-15', '143/2015', '143-2015']
# FOUND 148/2014
# GOT 519 148/2014 ['148/14', '148-14', '148/2014', '148-2014']
# FOUND 193/2018
# GOT 522 193/2018 ['193/18', '193-18', '193/2018', '193-2018']
# GOT 522 206/2016 ['206/16', '206-16', '206/2016', '206-2016']
# FOUND 227/2014
# GOT 525 227/2014 ['227/14', '227-14', '227/2014', '227-2014']
# FOUND 227/2017
# GOT 528 227/2017 ['227/17', '227-17', '227/2017', '227-2017']
# GOT 532 None ['260/17', '260-17', '260/2017', '260-2017']
# FOUND 117/2013
# GOT 535 117/2013 ['117/13', '117-13', '117/2013', '117-2013']
# FOUND 155/2016
# GOT 538 155/2016 ['155/16', '155-16', '155/2016', '155-2016']
# FOUND 163-2015
# GOT 542 163-2015 ['163/15', '163-15', '163/2015', '163-2015']
# <h3>activities</h3>
# <table>
# <thead>
# <tr><th style="text-align: right;">  #</th><th style="text-align: right;">    catalog_number
# (integer)</th><th>tenders
# (array)                                                                                                         </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  1</td><td style="text-align: right;"> 14</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;שירותי הדרכה שיקומית לאדם העיוור וללקויי הראייה מלידה עד גיל 3 ...</td></tr>
# <tr><td style="text-align: right;">  2</td><td style="text-align: right;">142</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הצטרפות למאגר ספקים ארצי להפעלת מעונות יום שיקומיים (מכרז משלי ...</td></tr>
# <tr><td style="text-align: right;">  3</td><td style="text-align: right;">143</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מסגרות לדיור חוץ ביתי עבור אוכלוסיית אגף השיקום, בפריסה  ...</td></tr>
# <tr><td style="text-align: right;">  4</td><td style="text-align: right;">145</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;מכרז לבניית  רשימת ספקים להפעלה של נופשונים לילדים, בני נוער ו ...</td></tr>
# <tr><td style="text-align: right;">  5</td><td style="text-align: right;">147</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת קייטנות לאוכלוסייה  על רצף האוטיזם  הפעלת קייטנות לאוכלו ...</td></tr>
# <tr><td style="text-align: right;">  6</td><td style="text-align: right;">648</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מרכזי תעסוקה לאנשים עם עיוורון או לקות ראיה, מכל המגזרים ...</td></tr>
# <tr><td style="text-align: right;">  7</td><td style="text-align: right;">667</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת בתי תלמיד לעיוורים וללקויי ראייה&#x27;, &#x27;page_url&#x27;: &#x27;https:// ...</td></tr>
# <tr><td style="text-align: right;">  8</td><td style="text-align: right;">712</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מסגרות לדיור חוץ ביתי עבור אוכלוסיית אגף השיקום, בפריסה  ...</td></tr>
# <tr><td style="text-align: right;">  9</td><td style="text-align: right;">713</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מסגרות לדיור חוץ ביתי עבור אוכלוסיית אגף השיקום, בפריסה  ...</td></tr>
# <tr><td style="text-align: right;"> 10</td><td style="text-align: right;">714</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מסגרות לדיור חוץ ביתי עבור אוכלוסיית אגף השיקום, בפריסה  ...</td></tr>
# <tr><td style="text-align: right;"> 11</td><td style="text-align: right;"> 75</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת תכניות מעבר להכנה לצה&quot;ל וליווי במהלך השירות הצבאי עבור צ ...</td></tr>
# <tr><td style="text-align: right;"> 12</td><td style="text-align: right;">786</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת שתי מסגרות חוץ ביתיות בקהילה לילדים ובני נוער, מכל המגזר ...</td></tr>
# <tr><td style="text-align: right;"> 13</td><td style="text-align: right;"> 82</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;רשימת ספקים להפעלת דירות או מערכי דיור בקהילה לאנשים עם מוגבלו ...</td></tr>
# <tr><td style="text-align: right;"> 14</td><td style="text-align: right;"> 84</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מרכז שיקום לאנשים עם עיוורון או לקות ראייה בגילאי 18 ומע ...</td></tr>
# <tr><td style="text-align: right;"> 15</td><td style="text-align: right;"> 87</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מרכז תעסוקה לאנשים עם עיוורון או לקות ראייה, בנתניה.&#x27;, &#x27; ...</td></tr>
# <tr><td style="text-align: right;"> 16</td><td style="text-align: right;"> 88</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מועדונים חברתיים לחירשים בוגרים דוברי שפת סימנים ואנשים  ...</td></tr>
# <tr><td style="text-align: right;"> 17</td><td style="text-align: right;">880</td><td>[{&#x27;decision&#x27;: &#x27;סגור&#x27;, &#x27;description&#x27;: &#x27;הפעלת מרכז יום לאנשים עם מוגבלות פיזית קשה ולאנשים עם פגיעת רא ...</td></tr>
# </tbody>
# </table>

# %%
social_services = requests.get('https://data-input.obudget.org/api/datarecords/social_service').json()
social_services = [x['value'] for x in social_services['result']]
cat_numbers = [str(x.get('catalog_number')) for x in social_services if 'catalog_number' in x]
l = len(cat_numbers)
cat_numbers = set(cat_numbers)
assert l == len(cat_numbers)
used = set()
updates = dict()
for i in items:
    cn = str(i.pop('catalog_number'))
    if cn not in used:
        if cn not in cat_numbers:
            ERRORS.append(f'שירות מספר {cn} לא נמצא במערכת')
        used.add(cn)
    updates.setdefault(cn, dict())
    updates[cn].update(i)
print(len(updates))
json.dump(updates, open('updates.json', 'w'))
# Out:
# 18

# %%
with open('errors.txt', 'w') as error_log:
    error_log.write('\n'.join(sorted(set(ERRORS))))
